# %% [markdown]
# # D2W10 Agentic RAG Notebook
#
# This notebook tests the same RAG pipeline used in the Streamlit app:
# - Local KB retrieval (FAISS)
# - Optional web search (Tavily)
# - Answer generation (Groq) with sources

# %%
# Load the main function from our project

from rag_agent import answer_question

# %%
res = answer_question("What is RAG?")
res["answer"]
# Out:
# 'RAG stands for Retrieval-Augmented Generation. It\'s a way for a model to answer questions by first finding relevant text and then using that information to write the final answer. This process involves a "retriever" that selects useful information from a large amount of text, and a "generator" that uses that information to write the answer. RAG helps reduce "hallucinations" (when a model makes things up) by showing where the information comes from.\n\nSources:\n- [1] data/kb.txt\n- [2] data/kb.txt'

# %%
res["sources"]
# Out:
# [{'source': 'data/kb.txt',
#   'content': 'Agentic RAG means an AI agent that can decide when to use tools.\nIt can search in a local knowledge base and also use web search tools.\n\nRAG (Retrieval-Augmented Generation) helps the model answer using real documents.\nThe model first retrieves relevant text, then reads it, and then writes the final answer.\n\nA retriever is a component that finds the most relevant text chunks using embeddings.\nIt does not generate text, it only selects useful information.'},
#  {'source': 'data/kb.txt',
#   'content': 'Vector embeddings turn text into numbers so similar texts are close to each other.\nFAISS is a vector database used to store and search these embeddings efficiently.\n\nUsing sources is important to reduce hallucinations.\nGood RAG systems always show where the information comes from.'}]
