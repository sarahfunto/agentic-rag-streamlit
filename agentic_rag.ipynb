# %%
# Agentic RAG (D2W10) - Notebook
# This notebook tests the RAG pipeline used by the Streamlit app.

from rag_agent import answer_question

# %%
answer_question("What is RAG?")

# %%
answer_question("Latest news about LangChain")
